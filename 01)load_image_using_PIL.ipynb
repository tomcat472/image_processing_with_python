# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
img=Image.open('thanminsoe.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x1280>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img_arr=np.asarray(img)
img_arr
# Out:
# array([[[159, 115,  66],
#         [160, 116,  67],
#         [160, 116,  67],
#         ...,
#         [165, 122,  69],
#         [166, 123,  70],
#         [167, 124,  71]],
#
#        [[149, 105,  56],
#         [149, 105,  56],
#         [149, 105,  56],
#         ...,
#         [163, 120,  67],
#         [164, 121,  68],
#         [165, 122,  69]],
#
#        [[146, 102,  53],
#         [146, 102,  53],
#         [147, 103,  54],
#         ...,
#         [161, 118,  65],
#         [162, 119,  66],
#         [162, 119,  66]],
#
#        ...,
#
#        [[117, 109, 107],
#         [ 98,  90,  88],
#         [ 92,  84,  82],
#         ...,
#         [ 83,  70,  53],
#         [ 95,  82,  63],
#         [112,  99,  80]],
#
#        [[122, 114, 112],
#         [104,  96,  94],
#         [ 98,  90,  88],
#         ...,
#         [ 81,  68,  49],
#         [ 96,  83,  64],
#         [122, 109,  90]],
#
#        [[135, 127, 125],
#         [123, 115, 113],
#         [125, 117, 115],
# ...

# %%
type(img_arr)
# Out:
# numpy.ndarray

# %%
img_arr.shape
# Out:
# (1280, 720, 3)

# %%
plt.imshow(img_arr)
